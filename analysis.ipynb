# %%
import numpy as np

# %%
X = np.load("dynamic_MAPE.npy")

# %%
Y = np.load("static_MAPE.npy")

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(X[0])
plt.plot(Y[0])

# %%
ax = plt.gca()
ax.set_ylim([0, 10])
plt.plot(X[0])
plt.plot(Y[0])

# %%
dynamic_single = np.load("dynamic_single.npy")

# %%
static_single = np.load("static_single.npy")

# %%
ax = plt.gca()
ax.set_ylim([0, 10])
plt.plot(dynamic_single[0])

# %%
ax = plt.gca()
ax.set_ylim([0, 10])
plt.plot(static_single[0])

# %%
time = 10

# %%
plt.plot(list(map(lambda x: np.mean(x), np.array_split(dynamic_single[0], dynamic_single.shape[1]/time))))

# %%
ax = plt.gca()
ax.set_ylim([0, 10])
plt.plot(list(map(lambda x: np.mean(x), np.array_split(dynamic_single[0], dynamic_single.shape[1]/time))))

# %%
plt.plot(list(map(lambda x: np.mean(x), np.array_split(static_single[0], static_single.shape[1]/time))))

# %%
ax = plt.gca()
ax.set_ylim([0, 10])
plt.plot(list(map(lambda x: np.mean(x), np.array_split(static_single[0], static_single.shape[1]/time))))
